# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


import sys 
import os
path = os.path.dirname(os.getcwd())
sys.path.append(path)
from lib import *

# Data Import
df = pd.read_csv(r'../data/DE_2021.csv')
ci_data_2021 = df['carbon_intensity_avg']

df = pd.read_csv(r'../data/projectcount_wikiDE_2015.csv')
clickData_hourly_2015 = df["De"]

costantCB = pd.read_csv(r'../data/CB_constant.csv')
adaptiveCB = pd.read_csv(r'../data/CB_adaptive.csv')

# %%
x = "ADAPTIVE_AVG_CB_"

ADAPTIVE_AVG_CB_carbonBudget = adaptiveCB["AVGCarbonBudget"]

ADAPTIVE_AVG_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
ADAPTIVE_AVG_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
ADAPTIVE_AVG_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
ADAPTIVE_AVG_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

ADAPTIVE_AVG_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
ADAPTIVE_AVG_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
ADAPTIVE_AVG_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
ADAPTIVE_AVG_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

ADAPTIVE_AVG_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
ADAPTIVE_AVG_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
ADAPTIVE_AVG_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
ADAPTIVE_AVG_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

ADAPTIVE_AVG_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
ADAPTIVE_AVG_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
ADAPTIVE_AVG_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
ADAPTIVE_AVG_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

ADAPTIVE_AVG_CB_a_HH = []
ADAPTIVE_AVG_CB_a_HL = []
ADAPTIVE_AVG_CB_a_LH = []
ADAPTIVE_AVG_CB_a_LL = []

ADAPTIVE_AVG_CB_b_HH = []
ADAPTIVE_AVG_CB_b_HL = []
ADAPTIVE_AVG_CB_b_LH = []
ADAPTIVE_AVG_CB_b_LL = []

ADAPTIVE_AVG_CB_c_HH = []
ADAPTIVE_AVG_CB_c_HL = []
ADAPTIVE_AVG_CB_c_LH = []
ADAPTIVE_AVG_CB_c_LL = []

ADAPTIVE_AVG_CB_d_HH = []
ADAPTIVE_AVG_CB_d_HL = []
ADAPTIVE_AVG_CB_d_LH = []
ADAPTIVE_AVG_CB_d_LL = []

ADAPTIVE_AVG_CB_a = []
ADAPTIVE_AVG_CB_b = []
ADAPTIVE_AVG_CB_c = []
ADAPTIVE_AVG_CB_d = []

# %%
x = "ADAPTIVE_MAX_CB_"

ADAPTIVE_MAX_CB_carbonBudget = adaptiveCB["MaxCarbonBudget"]

ADAPTIVE_MAX_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
ADAPTIVE_MAX_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
ADAPTIVE_MAX_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
ADAPTIVE_MAX_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

ADAPTIVE_MAX_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
ADAPTIVE_MAX_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
ADAPTIVE_MAX_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
ADAPTIVE_MAX_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

ADAPTIVE_MAX_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
ADAPTIVE_MAX_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
ADAPTIVE_MAX_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
ADAPTIVE_MAX_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

ADAPTIVE_MAX_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
ADAPTIVE_MAX_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
ADAPTIVE_MAX_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
ADAPTIVE_MAX_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

ADAPTIVE_MAX_CB_a_HH = []
ADAPTIVE_MAX_CB_a_HL = []
ADAPTIVE_MAX_CB_a_LH = []
ADAPTIVE_MAX_CB_a_LL = []

ADAPTIVE_MAX_CB_b_HH = []
ADAPTIVE_MAX_CB_b_HL = []
ADAPTIVE_MAX_CB_b_LH = []
ADAPTIVE_MAX_CB_b_LL = []

ADAPTIVE_MAX_CB_c_HH = []
ADAPTIVE_MAX_CB_c_HL = []
ADAPTIVE_MAX_CB_c_LH = []
ADAPTIVE_MAX_CB_c_LL = []

ADAPTIVE_MAX_CB_d_HH = []
ADAPTIVE_MAX_CB_d_HL = []
ADAPTIVE_MAX_CB_d_LH = []
ADAPTIVE_MAX_CB_d_LL = []

ADAPTIVE_MAX_CB_a = []
ADAPTIVE_MAX_CB_b = []
ADAPTIVE_MAX_CB_c = []
ADAPTIVE_MAX_CB_d = []

# %%
x = "ADAPTIVE_MIN_CB_"

ADAPTIVE_MIN_CB_carbonBudget = adaptiveCB["MinCarbonBudget"]

ADAPTIVE_MIN_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
ADAPTIVE_MIN_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
ADAPTIVE_MIN_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
ADAPTIVE_MIN_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

ADAPTIVE_MIN_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
ADAPTIVE_MIN_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
ADAPTIVE_MIN_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
ADAPTIVE_MIN_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

ADAPTIVE_MIN_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
ADAPTIVE_MIN_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
ADAPTIVE_MIN_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
ADAPTIVE_MIN_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

ADAPTIVE_MIN_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
ADAPTIVE_MIN_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
ADAPTIVE_MIN_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
ADAPTIVE_MIN_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

ADAPTIVE_MIN_CB_a_HH = []
ADAPTIVE_MIN_CB_a_HL = []
ADAPTIVE_MIN_CB_a_LH = []
ADAPTIVE_MIN_CB_a_LL = []

ADAPTIVE_MIN_CB_b_HH = []
ADAPTIVE_MIN_CB_b_HL = []
ADAPTIVE_MIN_CB_b_LH = []
ADAPTIVE_MIN_CB_b_LL = []

ADAPTIVE_MIN_CB_c_HH = []
ADAPTIVE_MIN_CB_c_HL = []
ADAPTIVE_MIN_CB_c_LH = []
ADAPTIVE_MIN_CB_c_LL = []

ADAPTIVE_MIN_CB_d_HH = []
ADAPTIVE_MIN_CB_d_HL = []
ADAPTIVE_MIN_CB_d_LH = []
ADAPTIVE_MIN_CB_d_LL = []

ADAPTIVE_MIN_CB_a = []
ADAPTIVE_MIN_CB_b = []
ADAPTIVE_MIN_CB_c = []
ADAPTIVE_MIN_CB_d = []

# %%
x = "CONSTANT_AVG_CB_"

CONSTANT_AVG_CB_carbonBudget = costantCB["AVGCarbonBudget"].values[0]

CONSTANT_AVG_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
CONSTANT_AVG_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
CONSTANT_AVG_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
CONSTANT_AVG_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

CONSTANT_AVG_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
CONSTANT_AVG_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
CONSTANT_AVG_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
CONSTANT_AVG_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

CONSTANT_AVG_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
CONSTANT_AVG_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
CONSTANT_AVG_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
CONSTANT_AVG_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

CONSTANT_AVG_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
CONSTANT_AVG_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
CONSTANT_AVG_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
CONSTANT_AVG_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

CONSTANT_AVG_CB_a_HH = []
CONSTANT_AVG_CB_a_HL = []
CONSTANT_AVG_CB_a_LH = []
CONSTANT_AVG_CB_a_LL = []

CONSTANT_AVG_CB_b_HH = []
CONSTANT_AVG_CB_b_HL = []
CONSTANT_AVG_CB_b_LH = []
CONSTANT_AVG_CB_b_LL = []

CONSTANT_AVG_CB_c_HH = []
CONSTANT_AVG_CB_c_HL = []
CONSTANT_AVG_CB_c_LH = []
CONSTANT_AVG_CB_c_LL = []

CONSTANT_AVG_CB_d_HH = []
CONSTANT_AVG_CB_d_HL = []
CONSTANT_AVG_CB_d_LH = []
CONSTANT_AVG_CB_d_LL = []

CONSTANT_AVG_CB_a = []
CONSTANT_AVG_CB_b = []
CONSTANT_AVG_CB_c = []
CONSTANT_AVG_CB_d = []

# %%
x = "CONSTANT_HIGH_CB_"

CONSTANT_HIGH_CB_carbonBudget = costantCB["HighCarbonBudget"].values[0]

CONSTANT_HIGH_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
CONSTANT_HIGH_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
CONSTANT_HIGH_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
CONSTANT_HIGH_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

CONSTANT_HIGH_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
CONSTANT_HIGH_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
CONSTANT_HIGH_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
CONSTANT_HIGH_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

CONSTANT_HIGH_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
CONSTANT_HIGH_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
CONSTANT_HIGH_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
CONSTANT_HIGH_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

CONSTANT_HIGH_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
CONSTANT_HIGH_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
CONSTANT_HIGH_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
CONSTANT_HIGH_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

CONSTANT_HIGH_CB_a_HH = []
CONSTANT_HIGH_CB_a_HL = []
CONSTANT_HIGH_CB_a_LH = []
CONSTANT_HIGH_CB_a_LL = []

CONSTANT_HIGH_CB_b_HH = []
CONSTANT_HIGH_CB_b_HL = []
CONSTANT_HIGH_CB_b_LH = []
CONSTANT_HIGH_CB_b_LL = []

CONSTANT_HIGH_CB_c_HH = []
CONSTANT_HIGH_CB_c_HL = []
CONSTANT_HIGH_CB_c_LH = []
CONSTANT_HIGH_CB_c_LL = []

CONSTANT_HIGH_CB_d_HH = []
CONSTANT_HIGH_CB_d_HL = []
CONSTANT_HIGH_CB_d_LH = []
CONSTANT_HIGH_CB_d_LL = []

CONSTANT_HIGH_CB_a = []
CONSTANT_HIGH_CB_b = []
CONSTANT_HIGH_CB_c = []
CONSTANT_HIGH_CB_d = []

# %%
x = "CONSTANT_LOW_CB_"

CONSTANT_LOW_CB_carbonBudget = costantCB["LowCarbonBudget"].values[0]

CONSTANT_LOW_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
CONSTANT_LOW_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
CONSTANT_LOW_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
CONSTANT_LOW_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

CONSTANT_LOW_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
CONSTANT_LOW_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
CONSTANT_LOW_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
CONSTANT_LOW_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

CONSTANT_LOW_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
CONSTANT_LOW_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
CONSTANT_LOW_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
CONSTANT_LOW_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

CONSTANT_LOW_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
CONSTANT_LOW_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
CONSTANT_LOW_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
CONSTANT_LOW_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

CONSTANT_LOW_CB_a_HH = []
CONSTANT_LOW_CB_a_HL = []
CONSTANT_LOW_CB_a_LH = []
CONSTANT_LOW_CB_a_LL = []

CONSTANT_LOW_CB_b_HH = []
CONSTANT_LOW_CB_b_HL = []
CONSTANT_LOW_CB_b_LH = []
CONSTANT_LOW_CB_b_LL = []

CONSTANT_LOW_CB_c_HH = []
CONSTANT_LOW_CB_c_HL = []
CONSTANT_LOW_CB_c_LH = []
CONSTANT_LOW_CB_c_LL = []

CONSTANT_LOW_CB_d_HH = []
CONSTANT_LOW_CB_d_HL = []
CONSTANT_LOW_CB_d_LH = []
CONSTANT_LOW_CB_d_LL = []

CONSTANT_LOW_CB_a = []
CONSTANT_LOW_CB_b = []
CONSTANT_LOW_CB_c = []
CONSTANT_LOW_CB_d = []

# %%
x = "CONSTANT_MAX_CB_"

CONSTANT_MAX_CB_carbonBudget = costantCB["MaxCarbonBudget"].values[0]

CONSTANT_MAX_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
CONSTANT_MAX_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
CONSTANT_MAX_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
CONSTANT_MAX_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

CONSTANT_MAX_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
CONSTANT_MAX_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
CONSTANT_MAX_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
CONSTANT_MAX_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

CONSTANT_MAX_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
CONSTANT_MAX_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
CONSTANT_MAX_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
CONSTANT_MAX_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

CONSTANT_MAX_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
CONSTANT_MAX_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
CONSTANT_MAX_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
CONSTANT_MAX_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

CONSTANT_MAX_CB_a_HH = []
CONSTANT_MAX_CB_a_HL = []
CONSTANT_MAX_CB_a_LH = []
CONSTANT_MAX_CB_a_LL = []

CONSTANT_MAX_CB_b_HH = []
CONSTANT_MAX_CB_b_HL = []
CONSTANT_MAX_CB_b_LH = []
CONSTANT_MAX_CB_b_LL = []

CONSTANT_MAX_CB_c_HH = []
CONSTANT_MAX_CB_c_HL = []
CONSTANT_MAX_CB_c_LH = []
CONSTANT_MAX_CB_c_LL = []

CONSTANT_MAX_CB_d_HH = []
CONSTANT_MAX_CB_d_HL = []
CONSTANT_MAX_CB_d_LH = []
CONSTANT_MAX_CB_d_LL = []

CONSTANT_MAX_CB_a = []
CONSTANT_MAX_CB_b = []
CONSTANT_MAX_CB_c = []
CONSTANT_MAX_CB_d = []

# %%
x = "CONSTANT_MIN_CB_"

CONSTANT_MIN_CB_carbonBudget = costantCB["MinCarbonBudget"].values[0]

CONSTANT_MIN_CB_optimization_HH = pd.read_csv("../results/HH/optimizedCarbonAware/" + x + "optimization_result_HH.csv")
CONSTANT_MIN_CB_optimization_HL = pd.read_csv("../results/HL/optimizedCarbonAware/" + x + "optimization_result_HL.csv")
CONSTANT_MIN_CB_optimization_LH = pd.read_csv("../results/LH/optimizedCarbonAware/" + x + "optimization_result_LH.csv")
CONSTANT_MIN_CB_optimization_LL = pd.read_csv("../results/LL/optimizedCarbonAware/" + x + "optimization_result_LL.csv")

CONSTANT_MIN_CB_highPerformance_HH = pd.read_csv("../results/HH/highPerformanceBaseline_HH.csv")
CONSTANT_MIN_CB_highPerformance_HL = pd.read_csv("../results/HL/highPerformanceBaseline_HL.csv")
CONSTANT_MIN_CB_highPerformance_LH = pd.read_csv("../results/LH/highPerformanceBaseline_LH.csv")
CONSTANT_MIN_CB_highPerformance_LL = pd.read_csv("../results/LL/highPerformanceBaseline_LL.csv")

CONSTANT_MIN_CB_simpleCarbonAware_HH = pd.read_csv("../results/HH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HH.csv")
CONSTANT_MIN_CB_simpleCarbonAware_HL = pd.read_csv("../results/HL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_HL.csv")
CONSTANT_MIN_CB_simpleCarbonAware_LH = pd.read_csv("../results/LH/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LH.csv")
CONSTANT_MIN_CB_simpleCarbonAware_LL = pd.read_csv("../results/LL/simpleCarbonAware/" + x + "simpleCarbonAwareBaseline_LL.csv")

CONSTANT_MIN_CB_sequentialCarbonAware_HH = pd.read_csv("../results/HH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HH.csv")
CONSTANT_MIN_CB_sequentialCarbonAware_HL = pd.read_csv("../results/Hl/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_HL.csv")
CONSTANT_MIN_CB_sequentialCarbonAware_LH = pd.read_csv("../results/LH/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LH.csv")
CONSTANT_MIN_CB_sequentialCarbonAware_LL = pd.read_csv("../results/LL/sequentialCarbonAware/" + x + "sequentialCarbonAwareBaseline_LL.csv")

CONSTANT_MIN_CB_a_HH = []
CONSTANT_MIN_CB_a_HL = []
CONSTANT_MIN_CB_a_LH = []
CONSTANT_MIN_CB_a_LL = []

CONSTANT_MIN_CB_b_HH = []
CONSTANT_MIN_CB_b_HL = []
CONSTANT_MIN_CB_b_LH = []
CONSTANT_MIN_CB_b_LL = []

CONSTANT_MIN_CB_c_HH = []
CONSTANT_MIN_CB_c_HL = []
CONSTANT_MIN_CB_c_LH = []
CONSTANT_MIN_CB_c_LL = []

CONSTANT_MIN_CB_d_HH = []
CONSTANT_MIN_CB_d_HL = []
CONSTANT_MIN_CB_d_LH = []
CONSTANT_MIN_CB_d_LL = []

CONSTANT_MIN_CB_a = []
CONSTANT_MIN_CB_b = []
CONSTANT_MIN_CB_c = []
CONSTANT_MIN_CB_d = []

# %%
for i in range(8670):
    #ADAPTIVE_AVG_CB_
    ADAPTIVE_AVG_CB_a_HH.append(ADAPTIVE_AVG_CB_optimization_HH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_a_HL.append(ADAPTIVE_AVG_CB_optimization_HL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_a_LH.append(ADAPTIVE_AVG_CB_optimization_LH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_a_LL.append(ADAPTIVE_AVG_CB_optimization_LL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])

    ADAPTIVE_AVG_CB_b_HH.append((ADAPTIVE_AVG_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_b_HL.append((ADAPTIVE_AVG_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_b_LH.append((ADAPTIVE_AVG_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_b_LL.append((ADAPTIVE_AVG_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_AVG_CB_carbonBudget[i])

    ADAPTIVE_AVG_CB_c_HH.append(ADAPTIVE_AVG_CB_simpleCarbonAware_HH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_c_HL.append(ADAPTIVE_AVG_CB_simpleCarbonAware_HL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_c_LH.append(ADAPTIVE_AVG_CB_simpleCarbonAware_LH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_c_LL.append(ADAPTIVE_AVG_CB_simpleCarbonAware_LL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])

    ADAPTIVE_AVG_CB_d_HH.append(ADAPTIVE_AVG_CB_sequentialCarbonAware_HH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_d_HL.append(ADAPTIVE_AVG_CB_sequentialCarbonAware_HL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_d_LH.append(ADAPTIVE_AVG_CB_sequentialCarbonAware_LH["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])
    ADAPTIVE_AVG_CB_d_LL.append(ADAPTIVE_AVG_CB_sequentialCarbonAware_LL["ce"][i] / ADAPTIVE_AVG_CB_carbonBudget[i])

    ADAPTIVE_AVG_CB_a.append(mean([ADAPTIVE_AVG_CB_a_HH[i], ADAPTIVE_AVG_CB_a_HL[i], ADAPTIVE_AVG_CB_a_LH[i], ADAPTIVE_AVG_CB_a_LL[i]]))
    ADAPTIVE_AVG_CB_b.append(mean([ADAPTIVE_AVG_CB_b_HH[i], ADAPTIVE_AVG_CB_b_HL[i], ADAPTIVE_AVG_CB_b_LH[i], ADAPTIVE_AVG_CB_b_LL[i]]))
    ADAPTIVE_AVG_CB_c.append(mean([ADAPTIVE_AVG_CB_c_HH[i], ADAPTIVE_AVG_CB_c_HL[i], ADAPTIVE_AVG_CB_c_LH[i], ADAPTIVE_AVG_CB_c_LL[i]]))
    ADAPTIVE_AVG_CB_d.append(mean([ADAPTIVE_AVG_CB_d_HH[i], ADAPTIVE_AVG_CB_d_HL[i], ADAPTIVE_AVG_CB_d_LH[i], ADAPTIVE_AVG_CB_d_LL[i]]))

    #ADAPTIVE_MAX_CB_
    ADAPTIVE_MAX_CB_a_HH.append(ADAPTIVE_MAX_CB_optimization_HH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_a_HL.append(ADAPTIVE_MAX_CB_optimization_HL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_a_LH.append(ADAPTIVE_MAX_CB_optimization_LH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_a_LL.append(ADAPTIVE_MAX_CB_optimization_LL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])

    ADAPTIVE_MAX_CB_b_HH.append((ADAPTIVE_MAX_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_b_HL.append((ADAPTIVE_MAX_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_b_LH.append((ADAPTIVE_MAX_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_b_LL.append((ADAPTIVE_MAX_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MAX_CB_carbonBudget[i])

    ADAPTIVE_MAX_CB_c_HH.append(ADAPTIVE_MAX_CB_simpleCarbonAware_HH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_c_HL.append(ADAPTIVE_MAX_CB_simpleCarbonAware_HL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_c_LH.append(ADAPTIVE_MAX_CB_simpleCarbonAware_LH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_c_LL.append(ADAPTIVE_MAX_CB_simpleCarbonAware_LL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])

    ADAPTIVE_MAX_CB_d_HH.append(ADAPTIVE_MAX_CB_sequentialCarbonAware_HH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_d_HL.append(ADAPTIVE_MAX_CB_sequentialCarbonAware_HL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_d_LH.append(ADAPTIVE_MAX_CB_sequentialCarbonAware_LH["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])
    ADAPTIVE_MAX_CB_d_LL.append(ADAPTIVE_MAX_CB_sequentialCarbonAware_LL["ce"][i] / ADAPTIVE_MAX_CB_carbonBudget[i])

    ADAPTIVE_MAX_CB_a.append(mean([ADAPTIVE_MAX_CB_a_HH[i], ADAPTIVE_MAX_CB_a_HL[i], ADAPTIVE_MAX_CB_a_LH[i], ADAPTIVE_MAX_CB_a_LL[i]]))
    ADAPTIVE_MAX_CB_b.append(mean([ADAPTIVE_MAX_CB_b_HH[i], ADAPTIVE_MAX_CB_b_HL[i], ADAPTIVE_MAX_CB_b_LH[i], ADAPTIVE_MAX_CB_b_LL[i]]))
    ADAPTIVE_MAX_CB_c.append(mean([ADAPTIVE_MAX_CB_c_HH[i], ADAPTIVE_MAX_CB_c_HL[i], ADAPTIVE_MAX_CB_c_LH[i], ADAPTIVE_MAX_CB_c_LL[i]]))
    ADAPTIVE_MAX_CB_d.append(mean([ADAPTIVE_MAX_CB_d_HH[i], ADAPTIVE_MAX_CB_d_HL[i], ADAPTIVE_MAX_CB_d_LH[i], ADAPTIVE_MAX_CB_d_LL[i]]))

    #ADAPTIVE_MIN_CB_
    ADAPTIVE_MIN_CB_a_HH.append(ADAPTIVE_MIN_CB_optimization_HH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_a_HL.append(ADAPTIVE_MIN_CB_optimization_HL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_a_LH.append(ADAPTIVE_MIN_CB_optimization_LH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_a_LL.append(ADAPTIVE_MIN_CB_optimization_LL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])

    ADAPTIVE_MIN_CB_b_HH.append((ADAPTIVE_MIN_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_b_HL.append((ADAPTIVE_MIN_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_b_LH.append((ADAPTIVE_MIN_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_b_LL.append((ADAPTIVE_MIN_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / ADAPTIVE_MIN_CB_carbonBudget[i])

    ADAPTIVE_MIN_CB_c_HH.append(ADAPTIVE_MIN_CB_simpleCarbonAware_HH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_c_HL.append(ADAPTIVE_MIN_CB_simpleCarbonAware_HL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_c_LH.append(ADAPTIVE_MIN_CB_simpleCarbonAware_LH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_c_LL.append(ADAPTIVE_MIN_CB_simpleCarbonAware_LL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])

    ADAPTIVE_MIN_CB_d_HH.append(ADAPTIVE_MIN_CB_sequentialCarbonAware_HH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_d_HL.append(ADAPTIVE_MIN_CB_sequentialCarbonAware_HL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_d_LH.append(ADAPTIVE_MIN_CB_sequentialCarbonAware_LH["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])
    ADAPTIVE_MIN_CB_d_LL.append(ADAPTIVE_MIN_CB_sequentialCarbonAware_LL["ce"][i] / ADAPTIVE_MIN_CB_carbonBudget[i])

    ADAPTIVE_MIN_CB_a.append(mean([ADAPTIVE_MIN_CB_a_HH[i], ADAPTIVE_MIN_CB_a_HL[i], ADAPTIVE_MIN_CB_a_LH[i], ADAPTIVE_MIN_CB_a_LL[i]]))
    ADAPTIVE_MIN_CB_b.append(mean([ADAPTIVE_MIN_CB_b_HH[i], ADAPTIVE_MIN_CB_b_HL[i], ADAPTIVE_MIN_CB_b_LH[i], ADAPTIVE_MIN_CB_b_LL[i]]))
    ADAPTIVE_MIN_CB_c.append(mean([ADAPTIVE_MIN_CB_c_HH[i], ADAPTIVE_MIN_CB_c_HL[i], ADAPTIVE_MIN_CB_c_LH[i], ADAPTIVE_MIN_CB_c_LL[i]]))
    ADAPTIVE_MIN_CB_d.append(mean([ADAPTIVE_MIN_CB_d_HH[i], ADAPTIVE_MIN_CB_d_HL[i], ADAPTIVE_MIN_CB_d_LH[i], ADAPTIVE_MIN_CB_d_LL[i]]))

    #CONSTANT_AVG_CB_
    CONSTANT_AVG_CB_a_HH.append(CONSTANT_AVG_CB_optimization_HH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_a_HL.append(CONSTANT_AVG_CB_optimization_HL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_a_LH.append(CONSTANT_AVG_CB_optimization_LH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_a_LL.append(CONSTANT_AVG_CB_optimization_LL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)

    CONSTANT_AVG_CB_b_HH.append((CONSTANT_AVG_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_b_HL.append((CONSTANT_AVG_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_b_LH.append((CONSTANT_AVG_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_b_LL.append((CONSTANT_AVG_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_AVG_CB_carbonBudget)

    CONSTANT_AVG_CB_c_HH.append(CONSTANT_AVG_CB_simpleCarbonAware_HH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_c_HL.append(CONSTANT_AVG_CB_simpleCarbonAware_HL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_c_LH.append(CONSTANT_AVG_CB_simpleCarbonAware_LH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_c_LL.append(CONSTANT_AVG_CB_simpleCarbonAware_LL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)

    CONSTANT_AVG_CB_d_HH.append(CONSTANT_AVG_CB_sequentialCarbonAware_HH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_d_HL.append(CONSTANT_AVG_CB_sequentialCarbonAware_HL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_d_LH.append(CONSTANT_AVG_CB_sequentialCarbonAware_LH["ce"][i] / CONSTANT_AVG_CB_carbonBudget)
    CONSTANT_AVG_CB_d_LL.append(CONSTANT_AVG_CB_sequentialCarbonAware_LL["ce"][i] / CONSTANT_AVG_CB_carbonBudget)

    CONSTANT_AVG_CB_a.append(mean([CONSTANT_AVG_CB_a_HH[i], CONSTANT_AVG_CB_a_HL[i], CONSTANT_AVG_CB_a_LH[i], CONSTANT_AVG_CB_a_LL[i]]))
    CONSTANT_AVG_CB_b.append(mean([CONSTANT_AVG_CB_b_HH[i], CONSTANT_AVG_CB_b_HL[i]+ CONSTANT_AVG_CB_b_LH[i]+ CONSTANT_AVG_CB_b_LL[i]]))
    CONSTANT_AVG_CB_c.append(mean([CONSTANT_AVG_CB_c_HH[i]+ CONSTANT_AVG_CB_c_HL[i]+ CONSTANT_AVG_CB_c_LH[i]+ CONSTANT_AVG_CB_c_LL[i]]))
    CONSTANT_AVG_CB_d.append(mean([CONSTANT_AVG_CB_d_HH[i]+ CONSTANT_AVG_CB_d_HL[i]+ CONSTANT_AVG_CB_d_LH[i], CONSTANT_AVG_CB_d_LL[i]]))

    #CONSTANT_HIGH_CB_
    CONSTANT_HIGH_CB_a_HH.append(CONSTANT_HIGH_CB_optimization_HH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_a_HL.append(CONSTANT_HIGH_CB_optimization_HL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_a_LH.append(CONSTANT_HIGH_CB_optimization_LH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_a_LL.append(CONSTANT_HIGH_CB_optimization_LL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)

    CONSTANT_HIGH_CB_b_HH.append((CONSTANT_HIGH_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_b_HL.append((CONSTANT_HIGH_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_b_LH.append((CONSTANT_HIGH_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_b_LL.append((CONSTANT_HIGH_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_HIGH_CB_carbonBudget)

    CONSTANT_HIGH_CB_c_HH.append(CONSTANT_HIGH_CB_simpleCarbonAware_HH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_c_HL.append(CONSTANT_HIGH_CB_simpleCarbonAware_HL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_c_LH.append(CONSTANT_HIGH_CB_simpleCarbonAware_LH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_c_LL.append(CONSTANT_HIGH_CB_simpleCarbonAware_LL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)

    CONSTANT_HIGH_CB_d_HH.append(CONSTANT_HIGH_CB_sequentialCarbonAware_HH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_d_HL.append(CONSTANT_HIGH_CB_sequentialCarbonAware_HL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_d_LH.append(CONSTANT_HIGH_CB_sequentialCarbonAware_LH["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)
    CONSTANT_HIGH_CB_d_LL.append(CONSTANT_HIGH_CB_sequentialCarbonAware_LL["ce"][i] / CONSTANT_HIGH_CB_carbonBudget)

    CONSTANT_HIGH_CB_a.append(mean([CONSTANT_HIGH_CB_a_HH[i], CONSTANT_HIGH_CB_a_HL[i], CONSTANT_HIGH_CB_a_LH[i], CONSTANT_HIGH_CB_a_LL[i]]))
    CONSTANT_HIGH_CB_b.append(mean([CONSTANT_HIGH_CB_b_HH[i], CONSTANT_HIGH_CB_b_HL[i], CONSTANT_HIGH_CB_b_LH[i], CONSTANT_HIGH_CB_b_LL[i]]))
    CONSTANT_HIGH_CB_c.append(mean([CONSTANT_HIGH_CB_c_HH[i], CONSTANT_HIGH_CB_c_HL[i], CONSTANT_HIGH_CB_c_LH[i], CONSTANT_HIGH_CB_c_LL[i]]))
    CONSTANT_HIGH_CB_d.append(mean([CONSTANT_HIGH_CB_d_HH[i], CONSTANT_HIGH_CB_d_HL[i], CONSTANT_HIGH_CB_d_LH[i], CONSTANT_HIGH_CB_d_LL[i]]))

    #CONSTANT_LOW_CB_
    CONSTANT_LOW_CB_a_HH.append(CONSTANT_LOW_CB_optimization_HH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_a_HL.append(CONSTANT_LOW_CB_optimization_HL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_a_LH.append(CONSTANT_LOW_CB_optimization_LH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_a_LL.append(CONSTANT_LOW_CB_optimization_LL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)

    CONSTANT_LOW_CB_b_HH.append((CONSTANT_LOW_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_b_HL.append((CONSTANT_LOW_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_b_LH.append((CONSTANT_LOW_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_b_LL.append((CONSTANT_LOW_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_LOW_CB_carbonBudget)

    CONSTANT_LOW_CB_c_HH.append(CONSTANT_LOW_CB_simpleCarbonAware_HH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_c_HL.append(CONSTANT_LOW_CB_simpleCarbonAware_HL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_c_LH.append(CONSTANT_LOW_CB_simpleCarbonAware_LH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_c_LL.append(CONSTANT_LOW_CB_simpleCarbonAware_LL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)

    CONSTANT_LOW_CB_d_HH.append(CONSTANT_LOW_CB_sequentialCarbonAware_HH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_d_HL.append(CONSTANT_LOW_CB_sequentialCarbonAware_HL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_d_LH.append(CONSTANT_LOW_CB_sequentialCarbonAware_LH["ce"][i] / CONSTANT_LOW_CB_carbonBudget)
    CONSTANT_LOW_CB_d_LL.append(CONSTANT_LOW_CB_sequentialCarbonAware_LL["ce"][i] / CONSTANT_LOW_CB_carbonBudget)

    CONSTANT_LOW_CB_a.append(mean([CONSTANT_LOW_CB_a_HH[i], CONSTANT_LOW_CB_a_HL[i], CONSTANT_LOW_CB_a_LH[i], CONSTANT_LOW_CB_a_LL[i]]))
    CONSTANT_LOW_CB_b.append(mean([CONSTANT_LOW_CB_b_HH[i], CONSTANT_LOW_CB_b_HL[i], CONSTANT_LOW_CB_b_LH[i], CONSTANT_LOW_CB_b_LL[i]]))
    CONSTANT_LOW_CB_c.append(mean([CONSTANT_LOW_CB_c_HH[i], CONSTANT_LOW_CB_c_HL[i], CONSTANT_LOW_CB_c_LH[i], CONSTANT_LOW_CB_c_LL[i]]))
    CONSTANT_LOW_CB_d.append(mean([CONSTANT_LOW_CB_d_HH[i], CONSTANT_LOW_CB_d_HL[i], CONSTANT_LOW_CB_d_LH[i], CONSTANT_LOW_CB_d_LL[i]]))

    #CONSTANT_MAX_CB_
    CONSTANT_MAX_CB_a_HH.append(CONSTANT_MAX_CB_optimization_HH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_a_HL.append(CONSTANT_MAX_CB_optimization_HL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_a_LH.append(CONSTANT_MAX_CB_optimization_LH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_a_LL.append(CONSTANT_MAX_CB_optimization_LL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)

    CONSTANT_MAX_CB_b_HH.append((CONSTANT_MAX_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_b_HL.append((CONSTANT_MAX_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_b_LH.append((CONSTANT_MAX_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_b_LL.append((CONSTANT_MAX_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MAX_CB_carbonBudget)

    CONSTANT_MAX_CB_c_HH.append(CONSTANT_MAX_CB_simpleCarbonAware_HH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_c_HL.append(CONSTANT_MAX_CB_simpleCarbonAware_HL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_c_LH.append(CONSTANT_MAX_CB_simpleCarbonAware_LH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_c_LL.append(CONSTANT_MAX_CB_simpleCarbonAware_LL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)

    CONSTANT_MAX_CB_d_HH.append(CONSTANT_MAX_CB_sequentialCarbonAware_HH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_d_HL.append(CONSTANT_MAX_CB_sequentialCarbonAware_HL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_d_LH.append(CONSTANT_MAX_CB_sequentialCarbonAware_LH["ce"][i] / CONSTANT_MAX_CB_carbonBudget)
    CONSTANT_MAX_CB_d_LL.append(CONSTANT_MAX_CB_sequentialCarbonAware_LL["ce"][i] / CONSTANT_MAX_CB_carbonBudget)

    CONSTANT_MAX_CB_a.append(mean([CONSTANT_MAX_CB_a_HH[i], CONSTANT_MAX_CB_a_HL[i], CONSTANT_MAX_CB_a_LH[i], CONSTANT_MAX_CB_a_LL[i]]))
    CONSTANT_MAX_CB_b.append(mean([CONSTANT_MAX_CB_b_HH[i], CONSTANT_MAX_CB_b_HL[i], CONSTANT_MAX_CB_b_LH[i], CONSTANT_MAX_CB_b_LL[i]]))
    CONSTANT_MAX_CB_c.append(mean([CONSTANT_MAX_CB_c_HH[i], CONSTANT_MAX_CB_c_HL[i], CONSTANT_MAX_CB_c_LH[i], CONSTANT_MAX_CB_c_LL[i]]))
    CONSTANT_MAX_CB_d.append(mean([CONSTANT_MAX_CB_d_HH[i], CONSTANT_MAX_CB_d_HL[i], CONSTANT_MAX_CB_d_LH[i], CONSTANT_MAX_CB_d_LL[i]]))

    #CONSTANT_MIN_CB_
    CONSTANT_MIN_CB_a_HH.append(CONSTANT_MIN_CB_optimization_HH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_a_HL.append(CONSTANT_MIN_CB_optimization_HL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_a_LH.append(CONSTANT_MIN_CB_optimization_LH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_a_LL.append(CONSTANT_MIN_CB_optimization_LL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)

    CONSTANT_MIN_CB_b_HH.append((CONSTANT_MIN_CB_highPerformance_HH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_b_HL.append((CONSTANT_MIN_CB_highPerformance_HL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_b_LH.append((CONSTANT_MIN_CB_highPerformance_LH["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_b_LL.append((CONSTANT_MIN_CB_highPerformance_LL["Energy demand"][i] * ci_data_2021[i]) / CONSTANT_MIN_CB_carbonBudget)

    CONSTANT_MIN_CB_c_HH.append(CONSTANT_MIN_CB_simpleCarbonAware_HH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_c_HL.append(CONSTANT_MIN_CB_simpleCarbonAware_HL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_c_LH.append(CONSTANT_MIN_CB_simpleCarbonAware_LH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_c_LL.append(CONSTANT_MIN_CB_simpleCarbonAware_LL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)

    CONSTANT_MIN_CB_d_HH.append(CONSTANT_MIN_CB_sequentialCarbonAware_HH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_d_HL.append(CONSTANT_MIN_CB_sequentialCarbonAware_HL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_d_LH.append(CONSTANT_MIN_CB_sequentialCarbonAware_LH["ce"][i] / CONSTANT_MIN_CB_carbonBudget)
    CONSTANT_MIN_CB_d_LL.append(CONSTANT_MIN_CB_sequentialCarbonAware_LL["ce"][i] / CONSTANT_MIN_CB_carbonBudget)

    CONSTANT_MIN_CB_a.append(mean([CONSTANT_MIN_CB_a_HH[i], CONSTANT_MIN_CB_a_HL[i], CONSTANT_MIN_CB_a_LH[i], CONSTANT_MIN_CB_a_LL[i]]))
    CONSTANT_MIN_CB_b.append(mean([CONSTANT_MIN_CB_b_HH[i], CONSTANT_MIN_CB_b_HL[i], CONSTANT_MIN_CB_b_LH[i], CONSTANT_MIN_CB_b_LL[i]]))
    CONSTANT_MIN_CB_c.append(mean([CONSTANT_MIN_CB_c_HH[i], CONSTANT_MIN_CB_c_HL[i], CONSTANT_MIN_CB_c_LH[i], CONSTANT_MIN_CB_c_LL[i]]))
    CONSTANT_MIN_CB_d.append(mean([CONSTANT_MIN_CB_d_HH[i], CONSTANT_MIN_CB_d_HL[i], CONSTANT_MIN_CB_d_LH[i], CONSTANT_MIN_CB_d_LL[i]]))

# %%
from matplotlib.patches import Rectangle

#ADAPTIVE_AVG_CB_
ADAPTIVE_AVG_CB_QoE_opt = (sum(ADAPTIVE_AVG_CB_optimization_HH['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_HL['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_LH['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_AVG_CB_QoE_HP = 1
ADAPTIVE_AVG_CB_QoE_sim = (sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_AVG_CB_QoE_seq = (sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_AVG_CB_CB_opt = (sum(ADAPTIVE_AVG_CB_a_HH) + sum(ADAPTIVE_AVG_CB_a_HL) + sum(ADAPTIVE_AVG_CB_a_LH) + sum(ADAPTIVE_AVG_CB_a_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_HP = (sum(ADAPTIVE_AVG_CB_b_HH) + sum(ADAPTIVE_AVG_CB_b_HL) + sum(ADAPTIVE_AVG_CB_b_LH) + sum(ADAPTIVE_AVG_CB_b_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_sim = (sum(ADAPTIVE_AVG_CB_c_HH) + sum(ADAPTIVE_AVG_CB_c_HL) + sum(ADAPTIVE_AVG_CB_c_LH) + sum(ADAPTIVE_AVG_CB_c_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_seq = (sum(ADAPTIVE_AVG_CB_d_HH) + sum(ADAPTIVE_AVG_CB_d_HL) + sum(ADAPTIVE_AVG_CB_d_LH) + sum(ADAPTIVE_AVG_CB_d_LL)) / (8760*4)

#ADAPTIVE_MAX_CB_
ADAPTIVE_MAX_CB_QoE_opt = (sum(ADAPTIVE_MAX_CB_optimization_HH['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_HL['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_LH['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_MAX_CB_QoE_HP = 1
ADAPTIVE_MAX_CB_QoE_sim = (sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_MAX_CB_QoE_seq = (sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_MAX_CB_CB_opt = (sum(ADAPTIVE_MAX_CB_a_HH) + sum(ADAPTIVE_MAX_CB_a_HL) + sum(ADAPTIVE_MAX_CB_a_LH) + sum(ADAPTIVE_MAX_CB_a_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_HP = (sum(ADAPTIVE_MAX_CB_b_HH) + sum(ADAPTIVE_MAX_CB_b_HL) + sum(ADAPTIVE_MAX_CB_b_LH) + sum(ADAPTIVE_MAX_CB_b_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_sim = (sum(ADAPTIVE_MAX_CB_c_HH) + sum(ADAPTIVE_MAX_CB_c_HL) + sum(ADAPTIVE_MAX_CB_c_LH) + sum(ADAPTIVE_MAX_CB_c_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_seq = (sum(ADAPTIVE_MAX_CB_d_HH) + sum(ADAPTIVE_MAX_CB_d_HL) + sum(ADAPTIVE_MAX_CB_d_LH) + sum(ADAPTIVE_MAX_CB_d_LL)) / (8760*4)

#ADAPTIVE_MIN_CB_
ADAPTIVE_MIN_CB_QoE_opt = (sum(ADAPTIVE_MIN_CB_optimization_HH['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_HL['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_LH['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_MIN_CB_QoE_HP = 1
ADAPTIVE_MIN_CB_QoE_sim = (sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_MIN_CB_QoE_seq = (sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_MIN_CB_CB_opt = (sum(ADAPTIVE_MIN_CB_a_HH) + sum(ADAPTIVE_MIN_CB_a_HL) + sum(ADAPTIVE_MIN_CB_a_LH) + sum(ADAPTIVE_MIN_CB_a_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_HP = (sum(ADAPTIVE_MIN_CB_b_HH) + sum(ADAPTIVE_MIN_CB_b_HL) + sum(ADAPTIVE_MIN_CB_b_LH) + sum(ADAPTIVE_MIN_CB_b_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_sim = (sum(ADAPTIVE_MIN_CB_c_HH) + sum(ADAPTIVE_MIN_CB_c_HL) + sum(ADAPTIVE_MIN_CB_c_LH) + sum(ADAPTIVE_MIN_CB_c_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_seq = (sum(ADAPTIVE_MIN_CB_d_HH) + sum(ADAPTIVE_MIN_CB_d_HL) + sum(ADAPTIVE_MIN_CB_d_LH) + sum(ADAPTIVE_MIN_CB_d_LL)) / (8760*4)

#CONSTANT_AVG_CB_
CONSTANT_AVG_CB_QoE_opt = (sum(CONSTANT_AVG_CB_optimization_HH['QoE']) + sum(CONSTANT_AVG_CB_optimization_HL['QoE']) + sum(CONSTANT_AVG_CB_optimization_LH['QoE']) + sum(CONSTANT_AVG_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_AVG_CB_QoE_HP = 1
CONSTANT_AVG_CB_QoE_sim = (sum(CONSTANT_AVG_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_AVG_CB_QoE_seq = (sum(CONSTANT_AVG_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_AVG_CB_CB_opt = (sum(CONSTANT_AVG_CB_a_HH) + sum(CONSTANT_AVG_CB_a_HL) + sum(CONSTANT_AVG_CB_a_LH) + sum(CONSTANT_AVG_CB_a_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_HP = (sum(CONSTANT_AVG_CB_b_HH) + sum(CONSTANT_AVG_CB_b_HL) + sum(CONSTANT_AVG_CB_b_LH) + sum(CONSTANT_AVG_CB_b_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_sim = (sum(CONSTANT_AVG_CB_c_HH) + sum(CONSTANT_AVG_CB_c_HL) + sum(CONSTANT_AVG_CB_c_LH) + sum(CONSTANT_AVG_CB_c_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_seq = (sum(CONSTANT_AVG_CB_d_HH) + sum(CONSTANT_AVG_CB_d_HL) + sum(CONSTANT_AVG_CB_d_LH) + sum(CONSTANT_AVG_CB_d_LL)) / (8760*4)

#CONSTANT_HIGH_CB_
CONSTANT_HIGH_CB_QoE_opt = (sum(CONSTANT_HIGH_CB_optimization_HH['QoE']) + sum(CONSTANT_HIGH_CB_optimization_HL['QoE']) + sum(CONSTANT_HIGH_CB_optimization_LH['QoE']) + sum(CONSTANT_HIGH_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_HIGH_CB_QoE_HP = 1
CONSTANT_HIGH_CB_QoE_sim = (sum(CONSTANT_HIGH_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_HIGH_CB_QoE_seq = (sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_HIGH_CB_CB_opt = (sum(CONSTANT_HIGH_CB_a_HH) + sum(CONSTANT_HIGH_CB_a_HL) + sum(CONSTANT_HIGH_CB_a_LH) + sum(CONSTANT_HIGH_CB_a_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_HP = (sum(CONSTANT_HIGH_CB_b_HH) + sum(CONSTANT_HIGH_CB_b_HL) + sum(CONSTANT_HIGH_CB_b_LH) + sum(CONSTANT_HIGH_CB_b_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_sim = (sum(CONSTANT_HIGH_CB_c_HH) + sum(CONSTANT_HIGH_CB_c_HL) + sum(CONSTANT_HIGH_CB_c_LH) + sum(CONSTANT_HIGH_CB_c_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_seq = (sum(CONSTANT_HIGH_CB_d_HH) + sum(CONSTANT_HIGH_CB_d_HL) + sum(CONSTANT_HIGH_CB_d_LH) + sum(CONSTANT_HIGH_CB_d_LL)) / (8760*4)

#CONSTANT_LOW_CB_
CONSTANT_LOW_CB_QoE_opt = (sum(CONSTANT_LOW_CB_optimization_HH['QoE']) + sum(CONSTANT_LOW_CB_optimization_HL['QoE']) + sum(CONSTANT_LOW_CB_optimization_LH['QoE']) + sum(CONSTANT_LOW_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_LOW_CB_QoE_HP = 1
CONSTANT_LOW_CB_QoE_sim = (sum(CONSTANT_LOW_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_LOW_CB_QoE_seq = (sum(CONSTANT_LOW_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_LOW_CB_CB_opt = (sum(CONSTANT_LOW_CB_a_HH) + sum(CONSTANT_LOW_CB_a_HL) + sum(CONSTANT_LOW_CB_a_LH) + sum(CONSTANT_LOW_CB_a_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_HP = (sum(CONSTANT_LOW_CB_b_HH) + sum(CONSTANT_LOW_CB_b_HL) + sum(CONSTANT_LOW_CB_b_LH) + sum(CONSTANT_LOW_CB_b_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_sim = (sum(CONSTANT_LOW_CB_c_HH) + sum(CONSTANT_LOW_CB_c_HL) + sum(CONSTANT_LOW_CB_c_LH) + sum(CONSTANT_LOW_CB_c_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_seq = (sum(CONSTANT_LOW_CB_d_HH) + sum(CONSTANT_LOW_CB_d_HL) + sum(CONSTANT_LOW_CB_d_LH) + sum(CONSTANT_LOW_CB_d_LL)) / (8760*4)

#CONSTANT_MAX_CB_
CONSTANT_MAX_CB_QoE_opt = (sum(CONSTANT_MAX_CB_optimization_HH['QoE']) + sum(CONSTANT_MAX_CB_optimization_HL['QoE']) + sum(CONSTANT_MAX_CB_optimization_LH['QoE']) + sum(CONSTANT_MAX_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_MAX_CB_QoE_HP = 1
CONSTANT_MAX_CB_QoE_sim = (sum(CONSTANT_MAX_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_MAX_CB_QoE_seq = (sum(CONSTANT_MAX_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_MAX_CB_CB_opt = (sum(CONSTANT_MAX_CB_a_HH) + sum(CONSTANT_MAX_CB_a_HL) + sum(CONSTANT_MAX_CB_a_LH) + sum(CONSTANT_MAX_CB_a_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_HP = (sum(CONSTANT_MAX_CB_b_HH) + sum(CONSTANT_MAX_CB_b_HL) + sum(CONSTANT_MAX_CB_b_LH) + sum(CONSTANT_MAX_CB_b_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_sim = (sum(CONSTANT_MAX_CB_c_HH) + sum(CONSTANT_MAX_CB_c_HL) + sum(CONSTANT_MAX_CB_c_LH) + sum(CONSTANT_MAX_CB_c_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_seq = (sum(CONSTANT_MAX_CB_d_HH) + sum(CONSTANT_MAX_CB_d_HL) + sum(CONSTANT_MAX_CB_d_LH) + sum(CONSTANT_MAX_CB_d_LL)) / (8760*4)

#CONSTANT_MIN_CB_
CONSTANT_MIN_CB_QoE_opt = (sum(CONSTANT_MIN_CB_optimization_HH['QoE']) + sum(CONSTANT_MIN_CB_optimization_HL['QoE']) + sum(CONSTANT_MIN_CB_optimization_LH['QoE']) + sum(CONSTANT_MIN_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_MIN_CB_QoE_HP = 1
CONSTANT_MIN_CB_QoE_sim = (sum(CONSTANT_MIN_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_MIN_CB_QoE_seq = (sum(CONSTANT_MIN_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_MIN_CB_CB_opt = (sum(CONSTANT_MIN_CB_a_HH) + sum(CONSTANT_MIN_CB_a_HL) + sum(CONSTANT_MIN_CB_a_LH) + sum(CONSTANT_MIN_CB_a_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_HP = (sum(CONSTANT_MIN_CB_b_HH) + sum(CONSTANT_MIN_CB_b_HL) + sum(CONSTANT_MIN_CB_b_LH) + sum(CONSTANT_MIN_CB_b_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_sim = (sum(CONSTANT_MIN_CB_c_HH) + sum(CONSTANT_MIN_CB_c_HL) + sum(CONSTANT_MIN_CB_c_LH) + sum(CONSTANT_MIN_CB_c_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_seq = (sum(CONSTANT_MIN_CB_d_HH) + sum(CONSTANT_MIN_CB_d_HL) + sum(CONSTANT_MIN_CB_d_LH) + sum(CONSTANT_MIN_CB_d_LL)) / (8760*4)



# Define plot limits 
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()

# Create a rectangle patch for the entire area
background_patch = Rectangle(xy=(0, 0),
                             width=x_max - x_min,
                             height=y_max - y_min,
                             color='lightgreen',  # Set to your desired color
                             alpha=0.5,  # Set transparency (0 to 1)
                             zorder=0.1)

# Add the patch to the axes 
ax = plt.gca()  # Get current axes object
ax.add_patch(background_patch)


# QoE values 
qoe_coord = [ADAPTIVE_AVG_CB_QoE_opt, ADAPTIVE_AVG_CB_QoE_HP, ADAPTIVE_AVG_CB_QoE_sim, ADAPTIVE_AVG_CB_QoE_seq, 
             ADAPTIVE_MAX_CB_QoE_opt, ADAPTIVE_MAX_CB_QoE_HP, ADAPTIVE_MAX_CB_QoE_sim, ADAPTIVE_MAX_CB_QoE_seq, 
             ADAPTIVE_MIN_CB_QoE_opt, ADAPTIVE_MIN_CB_QoE_HP, ADAPTIVE_MIN_CB_QoE_sim, ADAPTIVE_MIN_CB_QoE_seq, 
             CONSTANT_AVG_CB_QoE_opt, CONSTANT_AVG_CB_QoE_HP, CONSTANT_AVG_CB_QoE_sim, CONSTANT_AVG_CB_QoE_seq,
             CONSTANT_HIGH_CB_QoE_opt, CONSTANT_HIGH_CB_QoE_HP, CONSTANT_HIGH_CB_QoE_sim, CONSTANT_HIGH_CB_QoE_seq, 
             CONSTANT_LOW_CB_QoE_opt, CONSTANT_LOW_CB_QoE_HP, CONSTANT_LOW_CB_QoE_sim, CONSTANT_LOW_CB_QoE_seq, 
             CONSTANT_MAX_CB_QoE_opt, CONSTANT_MAX_CB_QoE_HP, CONSTANT_MAX_CB_QoE_sim, CONSTANT_MAX_CB_QoE_seq, 
             CONSTANT_MIN_CB_QoE_opt, CONSTANT_MIN_CB_QoE_HP, CONSTANT_MIN_CB_QoE_sim, CONSTANT_MIN_CB_QoE_seq]

# CB values 
cb_coord = [ADAPTIVE_AVG_CB_CB_opt, ADAPTIVE_AVG_CB_CB_HP, ADAPTIVE_AVG_CB_CB_sim, ADAPTIVE_AVG_CB_CB_seq,
            ADAPTIVE_MAX_CB_CB_opt, ADAPTIVE_MAX_CB_CB_HP, ADAPTIVE_MAX_CB_CB_sim, ADAPTIVE_MAX_CB_CB_seq,
            ADAPTIVE_MIN_CB_CB_opt, ADAPTIVE_MIN_CB_CB_HP, ADAPTIVE_MIN_CB_CB_sim, ADAPTIVE_MIN_CB_CB_seq,
            CONSTANT_AVG_CB_CB_opt, CONSTANT_AVG_CB_CB_HP, CONSTANT_AVG_CB_CB_sim, CONSTANT_AVG_CB_CB_seq,
            CONSTANT_HIGH_CB_CB_opt, CONSTANT_HIGH_CB_CB_HP, CONSTANT_HIGH_CB_CB_sim, CONSTANT_HIGH_CB_CB_seq,
            CONSTANT_LOW_CB_CB_opt, CONSTANT_LOW_CB_CB_HP, CONSTANT_LOW_CB_CB_sim, CONSTANT_LOW_CB_CB_seq,
            CONSTANT_MAX_CB_CB_opt, CONSTANT_MAX_CB_CB_HP, CONSTANT_MAX_CB_CB_sim, CONSTANT_MAX_CB_CB_seq,
            CONSTANT_MIN_CB_CB_opt, CONSTANT_MIN_CB_CB_HP, CONSTANT_MIN_CB_CB_sim, CONSTANT_MIN_CB_CB_seq]

# Labels for QoE data points
labels = ['Selective optimization', 'High Performance', 'Simple CA', 'Sequential CA']

shape = ['p', 'x', 'o', '*'] * 8

colors = (['#2CC820'] + ['#FB5534'] + ['#22CAD8'] + ['orange']) * 8 

plt.ylim(0, 1.2)  # Set Y-axis limits from 0 to 1
plt.xlim(xmin=0, xmax=4)


# Plot QoE data points with individual labels
for i, (w, z) in enumerate(zip(cb_coord, qoe_coord)):
    if i<4:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
    else:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)

print("Ad_MAX: ", ADAPTIVE_MAX_CB_QoE_opt, ADAPTIVE_MAX_CB_QoE_HP, ADAPTIVE_MAX_CB_QoE_sim, ADAPTIVE_MAX_CB_QoE_seq)
print("Ad_AVG: ", ADAPTIVE_AVG_CB_QoE_opt, ADAPTIVE_AVG_CB_QoE_HP, ADAPTIVE_AVG_CB_QoE_sim, ADAPTIVE_AVG_CB_QoE_seq)
print("Ad_MIN: ", ADAPTIVE_MIN_CB_QoE_opt, ADAPTIVE_MIN_CB_QoE_HP, ADAPTIVE_MIN_CB_QoE_sim, ADAPTIVE_MIN_CB_QoE_seq)
print("Cs_MAX: ", CONSTANT_MAX_CB_QoE_opt, CONSTANT_MAX_CB_QoE_HP, CONSTANT_MAX_CB_QoE_sim, CONSTANT_MAX_CB_QoE_seq)
print("Cs_HIGH: ", CONSTANT_HIGH_CB_QoE_opt, CONSTANT_HIGH_CB_QoE_HP, CONSTANT_HIGH_CB_QoE_sim, CONSTANT_HIGH_CB_QoE_seq)
print("Cs_AVG: ", CONSTANT_AVG_CB_QoE_opt, CONSTANT_AVG_CB_QoE_HP, CONSTANT_AVG_CB_QoE_sim, CONSTANT_AVG_CB_QoE_seq)
print("Cs_LOW: ", CONSTANT_LOW_CB_QoE_opt, CONSTANT_LOW_CB_QoE_HP, CONSTANT_LOW_CB_QoE_sim, CONSTANT_LOW_CB_QoE_seq)
print("Cs_MIN: ", CONSTANT_MIN_CB_QoE_opt, CONSTANT_MIN_CB_QoE_HP, CONSTANT_MIN_CB_QoE_sim, CONSTANT_MIN_CB_QoE_seq)

print(ADAPTIVE_MAX_CB_QoE_opt - ADAPTIVE_MAX_CB_QoE_sim)
print(ADAPTIVE_AVG_CB_QoE_opt - ADAPTIVE_AVG_CB_QoE_sim)
print(ADAPTIVE_MIN_CB_QoE_opt - ADAPTIVE_MIN_CB_QoE_sim)
print(CONSTANT_MAX_CB_QoE_opt - CONSTANT_MAX_CB_QoE_sim)
print(CONSTANT_HIGH_CB_QoE_opt - CONSTANT_HIGH_CB_QoE_sim)
print(CONSTANT_AVG_CB_QoE_opt - CONSTANT_AVG_CB_QoE_sim)
print(CONSTANT_LOW_CB_QoE_opt - CONSTANT_LOW_CB_QoE_sim)
print(CONSTANT_MIN_CB_QoE_opt - CONSTANT_MIN_CB_QoE_sim)

print(((ADAPTIVE_MAX_CB_QoE_opt - ADAPTIVE_MAX_CB_QoE_sim)+
      (ADAPTIVE_AVG_CB_QoE_opt - ADAPTIVE_AVG_CB_QoE_sim)+
      (ADAPTIVE_MIN_CB_QoE_opt - ADAPTIVE_MIN_CB_QoE_sim)+
      (CONSTANT_MAX_CB_QoE_opt - CONSTANT_MAX_CB_QoE_sim)+
      (CONSTANT_HIGH_CB_QoE_opt - CONSTANT_HIGH_CB_QoE_sim)+
      (CONSTANT_AVG_CB_QoE_opt - CONSTANT_AVG_CB_QoE_sim)+
      (CONSTANT_LOW_CB_QoE_opt - CONSTANT_LOW_CB_QoE_sim)+
      (CONSTANT_MIN_CB_QoE_opt - CONSTANT_MIN_CB_QoE_sim)) / 8)

# Label the axes
plt.xlabel('Carbon Budget % (CB)')
plt.ylabel('Quality of Experience % (QoE)')

# Add a title 
plt.title('QoE vs. Carbon Budget')

# Add legend
plt.legend()
plt.savefig("../img/temp/multiObjective.png", bbox_inches = "tight")
# Show the plot
plt.show()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\4115135225.py:144: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\4115135225.py:146: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)
# Ad_MAX:  0.8977363013698375 1 0.8532208904109257 0.8532488584474555
# Ad_AVG:  0.8103016552511215 1 0.6966198630136529 0.6966369863013241
# Ad_MIN:  0.40565525114155987 1 0.3216934931507153 0.3216501141552816
# ...

# %%
from matplotlib.patches import Rectangle

#ADAPTIVE_AVG_CB_
ADAPTIVE_AVG_CB_rev_opt = (sum(ADAPTIVE_AVG_CB_optimization_HH['rev in percentage']) + sum(ADAPTIVE_AVG_CB_optimization_HL['rev in percentage']) + sum(ADAPTIVE_AVG_CB_optimization_LH['rev in percentage']) + sum(ADAPTIVE_AVG_CB_optimization_LL['rev in percentage'])) / (4*8760)
ADAPTIVE_AVG_CB_rev_HP = 1
ADAPTIVE_AVG_CB_rev_sim = (sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
ADAPTIVE_AVG_CB_rev_seq = (sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

ADAPTIVE_AVG_CB_CB_opt = (sum(ADAPTIVE_AVG_CB_a_HH) + sum(ADAPTIVE_AVG_CB_a_HL) + sum(ADAPTIVE_AVG_CB_a_LH) + sum(ADAPTIVE_AVG_CB_a_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_HP = (sum(ADAPTIVE_AVG_CB_b_HH) + sum(ADAPTIVE_AVG_CB_b_HL) + sum(ADAPTIVE_AVG_CB_b_LH) + sum(ADAPTIVE_AVG_CB_b_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_sim = (sum(ADAPTIVE_AVG_CB_c_HH) + sum(ADAPTIVE_AVG_CB_c_HL) + sum(ADAPTIVE_AVG_CB_c_LH) + sum(ADAPTIVE_AVG_CB_c_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_seq = (sum(ADAPTIVE_AVG_CB_d_HH) + sum(ADAPTIVE_AVG_CB_d_HL) + sum(ADAPTIVE_AVG_CB_d_LH) + sum(ADAPTIVE_AVG_CB_d_LL)) / (8760*4)

#ADAPTIVE_MAX_CB_
ADAPTIVE_MAX_CB_rev_opt = (sum(ADAPTIVE_MAX_CB_optimization_HH['rev in percentage']) + sum(ADAPTIVE_MAX_CB_optimization_HL['rev in percentage']) + sum(ADAPTIVE_MAX_CB_optimization_LH['rev in percentage']) + sum(ADAPTIVE_MAX_CB_optimization_LL['rev in percentage'])) / (4*8760)
ADAPTIVE_MAX_CB_rev_HP = 1
ADAPTIVE_MAX_CB_rev_sim = (sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
ADAPTIVE_MAX_CB_rev_seq = (sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

ADAPTIVE_MAX_CB_CB_opt = (sum(ADAPTIVE_MAX_CB_a_HH) + sum(ADAPTIVE_MAX_CB_a_HL) + sum(ADAPTIVE_MAX_CB_a_LH) + sum(ADAPTIVE_MAX_CB_a_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_HP = (sum(ADAPTIVE_MAX_CB_b_HH) + sum(ADAPTIVE_MAX_CB_b_HL) + sum(ADAPTIVE_MAX_CB_b_LH) + sum(ADAPTIVE_MAX_CB_b_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_sim = (sum(ADAPTIVE_MAX_CB_c_HH) + sum(ADAPTIVE_MAX_CB_c_HL) + sum(ADAPTIVE_MAX_CB_c_LH) + sum(ADAPTIVE_MAX_CB_c_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_seq = (sum(ADAPTIVE_MAX_CB_d_HH) + sum(ADAPTIVE_MAX_CB_d_HL) + sum(ADAPTIVE_MAX_CB_d_LH) + sum(ADAPTIVE_MAX_CB_d_LL)) / (8760*4)

#ADAPTIVE_MIN_CB_
ADAPTIVE_MIN_CB_rev_opt = (sum(ADAPTIVE_MIN_CB_optimization_HH['rev in percentage']) + sum(ADAPTIVE_MIN_CB_optimization_HL['rev in percentage']) + sum(ADAPTIVE_MIN_CB_optimization_LH['rev in percentage']) + sum(ADAPTIVE_MIN_CB_optimization_LL['rev in percentage'])) / (4*8760)
ADAPTIVE_MIN_CB_rev_HP = 1
ADAPTIVE_MIN_CB_rev_sim = (sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
ADAPTIVE_MIN_CB_rev_seq = (sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

ADAPTIVE_MIN_CB_CB_opt = (sum(ADAPTIVE_MIN_CB_a_HH) + sum(ADAPTIVE_MIN_CB_a_HL) + sum(ADAPTIVE_MIN_CB_a_LH) + sum(ADAPTIVE_MIN_CB_a_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_HP = (sum(ADAPTIVE_MIN_CB_b_HH) + sum(ADAPTIVE_MIN_CB_b_HL) + sum(ADAPTIVE_MIN_CB_b_LH) + sum(ADAPTIVE_MIN_CB_b_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_sim = (sum(ADAPTIVE_MIN_CB_c_HH) + sum(ADAPTIVE_MIN_CB_c_HL) + sum(ADAPTIVE_MIN_CB_c_LH) + sum(ADAPTIVE_MIN_CB_c_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_seq = (sum(ADAPTIVE_MIN_CB_d_HH) + sum(ADAPTIVE_MIN_CB_d_HL) + sum(ADAPTIVE_MIN_CB_d_LH) + sum(ADAPTIVE_MIN_CB_d_LL)) / (8760*4)

#CONSTANT_AVG_CB_
CONSTANT_AVG_CB_rev_opt = (sum(CONSTANT_AVG_CB_optimization_HH['rev in percentage']) + sum(CONSTANT_AVG_CB_optimization_HL['rev in percentage']) + sum(CONSTANT_AVG_CB_optimization_LH['rev in percentage']) + sum(CONSTANT_AVG_CB_optimization_LL['rev in percentage'])) / (4*8760)
CONSTANT_AVG_CB_rev_HP = 1
CONSTANT_AVG_CB_rev_sim = (sum(CONSTANT_AVG_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
CONSTANT_AVG_CB_rev_seq = (sum(CONSTANT_AVG_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

CONSTANT_AVG_CB_CB_opt = (sum(CONSTANT_AVG_CB_a_HH) + sum(CONSTANT_AVG_CB_a_HL) + sum(CONSTANT_AVG_CB_a_LH) + sum(CONSTANT_AVG_CB_a_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_HP = (sum(CONSTANT_AVG_CB_b_HH) + sum(CONSTANT_AVG_CB_b_HL) + sum(CONSTANT_AVG_CB_b_LH) + sum(CONSTANT_AVG_CB_b_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_sim = (sum(CONSTANT_AVG_CB_c_HH) + sum(CONSTANT_AVG_CB_c_HL) + sum(CONSTANT_AVG_CB_c_LH) + sum(CONSTANT_AVG_CB_c_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_seq = (sum(CONSTANT_AVG_CB_d_HH) + sum(CONSTANT_AVG_CB_d_HL) + sum(CONSTANT_AVG_CB_d_LH) + sum(CONSTANT_AVG_CB_d_LL)) / (8760*4)

#CONSTANT_HIGH_CB_
CONSTANT_HIGH_CB_rev_opt = (sum(CONSTANT_HIGH_CB_optimization_HH['rev in percentage']) + sum(CONSTANT_HIGH_CB_optimization_HL['rev in percentage']) + sum(CONSTANT_HIGH_CB_optimization_LH['rev in percentage']) + sum(CONSTANT_HIGH_CB_optimization_LL['rev in percentage'])) / (4*8760)
CONSTANT_HIGH_CB_rev_HP = 1
CONSTANT_HIGH_CB_rev_sim = (sum(CONSTANT_HIGH_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
CONSTANT_HIGH_CB_rev_seq = (sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

CONSTANT_HIGH_CB_CB_opt = (sum(CONSTANT_HIGH_CB_a_HH) + sum(CONSTANT_HIGH_CB_a_HL) + sum(CONSTANT_HIGH_CB_a_LH) + sum(CONSTANT_HIGH_CB_a_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_HP = (sum(CONSTANT_HIGH_CB_b_HH) + sum(CONSTANT_HIGH_CB_b_HL) + sum(CONSTANT_HIGH_CB_b_LH) + sum(CONSTANT_HIGH_CB_b_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_sim = (sum(CONSTANT_HIGH_CB_c_HH) + sum(CONSTANT_HIGH_CB_c_HL) + sum(CONSTANT_HIGH_CB_c_LH) + sum(CONSTANT_HIGH_CB_c_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_seq = (sum(CONSTANT_HIGH_CB_d_HH) + sum(CONSTANT_HIGH_CB_d_HL) + sum(CONSTANT_HIGH_CB_d_LH) + sum(CONSTANT_HIGH_CB_d_LL)) / (8760*4)

#CONSTANT_LOW_CB_
CONSTANT_LOW_CB_rev_opt = (sum(CONSTANT_LOW_CB_optimization_HH['rev in percentage']) + sum(CONSTANT_LOW_CB_optimization_HL['rev in percentage']) + sum(CONSTANT_LOW_CB_optimization_LH['rev in percentage']) + sum(CONSTANT_LOW_CB_optimization_LL['rev in percentage'])) / (4*8760)
CONSTANT_LOW_CB_rev_HP = 1
CONSTANT_LOW_CB_rev_sim = (sum(CONSTANT_LOW_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
CONSTANT_LOW_CB_rev_seq = (sum(CONSTANT_LOW_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

CONSTANT_LOW_CB_CB_opt = (sum(CONSTANT_LOW_CB_a_HH) + sum(CONSTANT_LOW_CB_a_HL) + sum(CONSTANT_LOW_CB_a_LH) + sum(CONSTANT_LOW_CB_a_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_HP = (sum(CONSTANT_LOW_CB_b_HH) + sum(CONSTANT_LOW_CB_b_HL) + sum(CONSTANT_LOW_CB_b_LH) + sum(CONSTANT_LOW_CB_b_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_sim = (sum(CONSTANT_LOW_CB_c_HH) + sum(CONSTANT_LOW_CB_c_HL) + sum(CONSTANT_LOW_CB_c_LH) + sum(CONSTANT_LOW_CB_c_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_seq = (sum(CONSTANT_LOW_CB_d_HH) + sum(CONSTANT_LOW_CB_d_HL) + sum(CONSTANT_LOW_CB_d_LH) + sum(CONSTANT_LOW_CB_d_LL)) / (8760*4)

#CONSTANT_MAX_CB_
CONSTANT_MAX_CB_rev_opt = (sum(CONSTANT_MAX_CB_optimization_HH['rev in percentage']) + sum(CONSTANT_MAX_CB_optimization_HL['rev in percentage']) + sum(CONSTANT_MAX_CB_optimization_LH['rev in percentage']) + sum(CONSTANT_MAX_CB_optimization_LL['rev in percentage'])) / (4*8760)
CONSTANT_MAX_CB_rev_HP = 1
CONSTANT_MAX_CB_rev_sim = (sum(CONSTANT_MAX_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
CONSTANT_MAX_CB_rev_seq = (sum(CONSTANT_MAX_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

CONSTANT_MAX_CB_CB_opt = (sum(CONSTANT_MAX_CB_a_HH) + sum(CONSTANT_MAX_CB_a_HL) + sum(CONSTANT_MAX_CB_a_LH) + sum(CONSTANT_MAX_CB_a_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_HP = (sum(CONSTANT_MAX_CB_b_HH) + sum(CONSTANT_MAX_CB_b_HL) + sum(CONSTANT_MAX_CB_b_LH) + sum(CONSTANT_MAX_CB_b_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_sim = (sum(CONSTANT_MAX_CB_c_HH) + sum(CONSTANT_MAX_CB_c_HL) + sum(CONSTANT_MAX_CB_c_LH) + sum(CONSTANT_MAX_CB_c_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_seq = (sum(CONSTANT_MAX_CB_d_HH) + sum(CONSTANT_MAX_CB_d_HL) + sum(CONSTANT_MAX_CB_d_LH) + sum(CONSTANT_MAX_CB_d_LL)) / (8760*4)

#CONSTANT_MIN_CB_
CONSTANT_MIN_CB_rev_opt = (sum(CONSTANT_MIN_CB_optimization_HH['rev in percentage']) + sum(CONSTANT_MIN_CB_optimization_HL['rev in percentage']) + sum(CONSTANT_MIN_CB_optimization_LH['rev in percentage']) + sum(CONSTANT_MIN_CB_optimization_LL['rev in percentage'])) / (4*8760)
CONSTANT_MIN_CB_rev_HP = 1
CONSTANT_MIN_CB_rev_sim = (sum(CONSTANT_MIN_CB_simpleCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LL['Revenue in percentage'])) / (4*8760)
CONSTANT_MIN_CB_rev_seq = (sum(CONSTANT_MIN_CB_sequentialCarbonAware_HH['Revenue in percentage']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_HL['Revenue in percentage']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LH['Revenue in percentage']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LL['Revenue in percentage'])) / (4*8760)

CONSTANT_MIN_CB_CB_opt = (sum(CONSTANT_MIN_CB_a_HH) + sum(CONSTANT_MIN_CB_a_HL) + sum(CONSTANT_MIN_CB_a_LH) + sum(CONSTANT_MIN_CB_a_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_HP = (sum(CONSTANT_MIN_CB_b_HH) + sum(CONSTANT_MIN_CB_b_HL) + sum(CONSTANT_MIN_CB_b_LH) + sum(CONSTANT_MIN_CB_b_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_sim = (sum(CONSTANT_MIN_CB_c_HH) + sum(CONSTANT_MIN_CB_c_HL) + sum(CONSTANT_MIN_CB_c_LH) + sum(CONSTANT_MIN_CB_c_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_seq = (sum(CONSTANT_MIN_CB_d_HH) + sum(CONSTANT_MIN_CB_d_HL) + sum(CONSTANT_MIN_CB_d_LH) + sum(CONSTANT_MIN_CB_d_LL)) / (8760*4)



# Define plot limits
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()

# Create a rectangle patch for the entire area
background_patch = Rectangle(xy=(0, 0),
                             width=x_max - x_min,
                             height=y_max - y_min,
                             color='lightgreen',  # Set to your desired color
                             alpha=0.5,  # Set transparency (0 to 1)
                             zorder=0.1)

# Add the patch to the axes 
ax = plt.gca()  # Get current axes object
ax.add_patch(background_patch)


# QoE values 
rev_coord = [ADAPTIVE_AVG_CB_rev_opt, ADAPTIVE_AVG_CB_rev_HP, ADAPTIVE_AVG_CB_rev_sim, ADAPTIVE_AVG_CB_rev_seq, 
             ADAPTIVE_MAX_CB_rev_opt, ADAPTIVE_MAX_CB_rev_HP, ADAPTIVE_MAX_CB_rev_sim, ADAPTIVE_MAX_CB_rev_seq, 
             ADAPTIVE_MIN_CB_rev_opt, ADAPTIVE_MIN_CB_rev_HP, ADAPTIVE_MIN_CB_rev_sim, ADAPTIVE_MIN_CB_rev_seq, 
             CONSTANT_AVG_CB_rev_opt, CONSTANT_AVG_CB_rev_HP, CONSTANT_AVG_CB_rev_sim, CONSTANT_AVG_CB_rev_seq,
             CONSTANT_HIGH_CB_rev_opt, CONSTANT_HIGH_CB_rev_HP, CONSTANT_HIGH_CB_rev_sim, CONSTANT_HIGH_CB_rev_seq, 
             CONSTANT_LOW_CB_rev_opt, CONSTANT_LOW_CB_rev_HP, CONSTANT_LOW_CB_rev_sim, CONSTANT_LOW_CB_rev_seq, 
             CONSTANT_MAX_CB_rev_opt, CONSTANT_MAX_CB_rev_HP, CONSTANT_MAX_CB_rev_sim, CONSTANT_MAX_CB_rev_seq, 
             CONSTANT_MIN_CB_rev_opt, CONSTANT_MIN_CB_rev_HP, CONSTANT_MIN_CB_rev_sim, CONSTANT_MIN_CB_rev_seq]

# CB values 
cb_coord = [ADAPTIVE_AVG_CB_CB_opt, ADAPTIVE_AVG_CB_CB_HP, ADAPTIVE_AVG_CB_CB_sim, ADAPTIVE_AVG_CB_CB_seq,
            ADAPTIVE_MAX_CB_CB_opt, ADAPTIVE_MAX_CB_CB_HP, ADAPTIVE_MAX_CB_CB_sim, ADAPTIVE_MAX_CB_CB_seq,
            ADAPTIVE_MIN_CB_CB_opt, ADAPTIVE_MIN_CB_CB_HP, ADAPTIVE_MIN_CB_CB_sim, ADAPTIVE_MIN_CB_CB_seq,
            CONSTANT_AVG_CB_CB_opt, CONSTANT_AVG_CB_CB_HP, CONSTANT_AVG_CB_CB_sim, CONSTANT_AVG_CB_CB_seq,
            CONSTANT_HIGH_CB_CB_opt, CONSTANT_HIGH_CB_CB_HP, CONSTANT_HIGH_CB_CB_sim, CONSTANT_HIGH_CB_CB_seq,
            CONSTANT_LOW_CB_CB_opt, CONSTANT_LOW_CB_CB_HP, CONSTANT_LOW_CB_CB_sim, CONSTANT_LOW_CB_CB_seq,
            CONSTANT_MAX_CB_CB_opt, CONSTANT_MAX_CB_CB_HP, CONSTANT_MAX_CB_CB_sim, CONSTANT_MAX_CB_CB_seq,
            CONSTANT_MIN_CB_CB_opt, CONSTANT_MIN_CB_CB_HP, CONSTANT_MIN_CB_CB_sim, CONSTANT_MIN_CB_CB_seq]

# Labels for QoE data points
labels = ['Selective optimization', 'High Performance', 'Simple CA', 'Sequential CA']

shape = ['p', 'x', 'o', '*'] * 8

colors = (['#2CC820'] + ['#FB5534'] + ['#22CAD8'] + ['orange']) * 8 

plt.ylim(0, 1.2)  # Set Y-axis limits from 0 to 1.2
plt.xlim(xmin=0, xmax=4)


# Plot rev data points with individual labels
for i, (w, z) in enumerate(zip(cb_coord, rev_coord)):
    if i<4:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
    else:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)

print("Ad_MAX: ", ADAPTIVE_MAX_CB_rev_opt, ADAPTIVE_MAX_CB_rev_HP, ADAPTIVE_MAX_CB_rev_sim, ADAPTIVE_MAX_CB_rev_seq)
print("Ad_AVG: ", ADAPTIVE_AVG_CB_rev_opt, ADAPTIVE_AVG_CB_rev_HP, ADAPTIVE_AVG_CB_rev_sim, ADAPTIVE_AVG_CB_rev_seq)
print("Ad_MIN: ", ADAPTIVE_MIN_CB_rev_opt, ADAPTIVE_MIN_CB_rev_HP, ADAPTIVE_MIN_CB_rev_sim, ADAPTIVE_MIN_CB_rev_seq)
print("Cs_MAX: ", CONSTANT_MAX_CB_rev_opt, CONSTANT_MAX_CB_rev_HP, CONSTANT_MAX_CB_rev_sim, CONSTANT_MAX_CB_rev_seq)
print("Cs_HIGH: ", CONSTANT_HIGH_CB_rev_opt, CONSTANT_HIGH_CB_rev_HP, CONSTANT_HIGH_CB_rev_sim, CONSTANT_HIGH_CB_rev_seq)
print("Cs_AVG: ", CONSTANT_AVG_CB_rev_opt, CONSTANT_AVG_CB_rev_HP, CONSTANT_AVG_CB_rev_sim, CONSTANT_AVG_CB_rev_seq)
print("Cs_LOW: ", CONSTANT_LOW_CB_rev_opt, CONSTANT_LOW_CB_rev_HP, CONSTANT_LOW_CB_rev_sim, CONSTANT_LOW_CB_rev_seq)
print("Cs_MIN: ", CONSTANT_MIN_CB_rev_opt, CONSTANT_MIN_CB_rev_HP, CONSTANT_MIN_CB_rev_sim, CONSTANT_MIN_CB_rev_seq)

print("Opt vs simple:")
print(ADAPTIVE_MAX_CB_rev_opt - ADAPTIVE_MAX_CB_rev_sim)
print(ADAPTIVE_AVG_CB_rev_opt - ADAPTIVE_AVG_CB_rev_sim)
print(ADAPTIVE_MIN_CB_rev_opt - ADAPTIVE_MIN_CB_rev_sim)
print(CONSTANT_MAX_CB_rev_opt - CONSTANT_MAX_CB_rev_sim)
print(CONSTANT_HIGH_CB_rev_opt - CONSTANT_HIGH_CB_rev_sim)
print(CONSTANT_AVG_CB_rev_opt - CONSTANT_AVG_CB_rev_sim)
print(CONSTANT_LOW_CB_rev_opt - CONSTANT_LOW_CB_rev_sim)
print(CONSTANT_MIN_CB_rev_opt - CONSTANT_MIN_CB_rev_sim)

print("Opt vs sequential")
print(ADAPTIVE_MAX_CB_rev_opt - ADAPTIVE_MAX_CB_rev_seq)
print(ADAPTIVE_AVG_CB_rev_opt - ADAPTIVE_AVG_CB_rev_seq)
print(ADAPTIVE_MIN_CB_rev_opt - ADAPTIVE_MIN_CB_rev_seq)
print(CONSTANT_MAX_CB_rev_opt - CONSTANT_MAX_CB_rev_seq)
print(CONSTANT_HIGH_CB_rev_opt - CONSTANT_HIGH_CB_rev_seq)
print(CONSTANT_AVG_CB_rev_opt - CONSTANT_AVG_CB_rev_seq)
print(CONSTANT_LOW_CB_rev_opt - CONSTANT_LOW_CB_rev_seq)
print(CONSTANT_MIN_CB_rev_opt - CONSTANT_MIN_CB_rev_seq)

print("opt vs sim on average:")
print(((ADAPTIVE_MAX_CB_rev_opt - ADAPTIVE_MAX_CB_rev_sim)+
      (ADAPTIVE_AVG_CB_rev_opt - ADAPTIVE_AVG_CB_rev_sim)+
      (ADAPTIVE_MIN_CB_rev_opt - ADAPTIVE_MIN_CB_rev_sim)+
      (CONSTANT_MAX_CB_rev_opt - CONSTANT_MAX_CB_rev_sim)+
      (CONSTANT_HIGH_CB_rev_opt - CONSTANT_HIGH_CB_rev_sim)+
      (CONSTANT_AVG_CB_rev_opt - CONSTANT_AVG_CB_rev_sim)+
      (CONSTANT_LOW_CB_rev_opt - CONSTANT_LOW_CB_rev_sim)+
      (CONSTANT_MIN_CB_rev_opt - CONSTANT_MIN_CB_rev_sim)) / 8)

print("opt vs seq on average:")
print(((ADAPTIVE_MAX_CB_rev_opt - ADAPTIVE_MAX_CB_rev_seq)+
      (ADAPTIVE_AVG_CB_rev_opt - ADAPTIVE_AVG_CB_rev_seq)+
      (ADAPTIVE_MIN_CB_rev_opt - ADAPTIVE_MIN_CB_rev_seq)+
      (CONSTANT_MAX_CB_rev_opt - CONSTANT_MAX_CB_rev_seq)+
      (CONSTANT_HIGH_CB_rev_opt - CONSTANT_HIGH_CB_rev_seq)+
      (CONSTANT_AVG_CB_rev_opt - CONSTANT_AVG_CB_rev_seq)+
      (CONSTANT_LOW_CB_rev_opt - CONSTANT_LOW_CB_rev_seq)+
      (CONSTANT_MIN_CB_rev_opt - CONSTANT_MIN_CB_rev_seq)) / 8)

# Label the axes
plt.xlabel('Carbon Budget % (CB)')
plt.ylabel('Revenue % (rev)')

# Add a title 
plt.title('Revenue vs. Carbon Budget')

# Add legend
plt.legend()
plt.savefig("../img/temp/multiObjectiveRevenue.png", bbox_inches = "tight")
# Show the plot
plt.show()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\1226753163.py:144: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\1226753163.py:146: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)
# Ad_MAX:  0.9763231631382313 1 0.44202988792029496 0.44203507679534687
# Ad_AVG:  0.8529265255292611 1 0.17870485678703363 0.1786581569115666
# Ad_MIN:  0.03821087588210864 1 0.0005136986301369861 0.0003061436280614361
# ...

# %%
from matplotlib.patches import Rectangle

#ADAPTIVE_AVG_CB_
ADAPTIVE_AVG_CB_QoE_opt = (sum(ADAPTIVE_AVG_CB_optimization_HH['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_HL['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_LH['QoE']) + sum(ADAPTIVE_AVG_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_AVG_CB_QoE_HP = 1
ADAPTIVE_AVG_CB_QoE_sim = (sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_AVG_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_AVG_CB_QoE_seq = (sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_AVG_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_AVG_CB_CB_opt = (sum(ADAPTIVE_AVG_CB_a_HH) + sum(ADAPTIVE_AVG_CB_a_HL) + sum(ADAPTIVE_AVG_CB_a_LH) + sum(ADAPTIVE_AVG_CB_a_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_HP = (sum(ADAPTIVE_AVG_CB_b_HH) + sum(ADAPTIVE_AVG_CB_b_HL) + sum(ADAPTIVE_AVG_CB_b_LH) + sum(ADAPTIVE_AVG_CB_b_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_sim = (sum(ADAPTIVE_AVG_CB_c_HH) + sum(ADAPTIVE_AVG_CB_c_HL) + sum(ADAPTIVE_AVG_CB_c_LH) + sum(ADAPTIVE_AVG_CB_c_LL)) / (8760*4)
ADAPTIVE_AVG_CB_CB_seq = (sum(ADAPTIVE_AVG_CB_d_HH) + sum(ADAPTIVE_AVG_CB_d_HL) + sum(ADAPTIVE_AVG_CB_d_LH) + sum(ADAPTIVE_AVG_CB_d_LL)) / (8760*4)

#ADAPTIVE_MAX_CB_
ADAPTIVE_MAX_CB_QoE_opt = (sum(ADAPTIVE_MAX_CB_optimization_HH['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_HL['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_LH['QoE']) + sum(ADAPTIVE_MAX_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_MAX_CB_QoE_HP = 1
ADAPTIVE_MAX_CB_QoE_sim = (sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_MAX_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_MAX_CB_QoE_seq = (sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_MAX_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_MAX_CB_CB_opt = (sum(ADAPTIVE_MAX_CB_a_HH) + sum(ADAPTIVE_MAX_CB_a_HL) + sum(ADAPTIVE_MAX_CB_a_LH) + sum(ADAPTIVE_MAX_CB_a_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_HP = (sum(ADAPTIVE_MAX_CB_b_HH) + sum(ADAPTIVE_MAX_CB_b_HL) + sum(ADAPTIVE_MAX_CB_b_LH) + sum(ADAPTIVE_MAX_CB_b_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_sim = (sum(ADAPTIVE_MAX_CB_c_HH) + sum(ADAPTIVE_MAX_CB_c_HL) + sum(ADAPTIVE_MAX_CB_c_LH) + sum(ADAPTIVE_MAX_CB_c_LL)) / (8760*4)
ADAPTIVE_MAX_CB_CB_seq = (sum(ADAPTIVE_MAX_CB_d_HH) + sum(ADAPTIVE_MAX_CB_d_HL) + sum(ADAPTIVE_MAX_CB_d_LH) + sum(ADAPTIVE_MAX_CB_d_LL)) / (8760*4)

#ADAPTIVE_MIN_CB_
ADAPTIVE_MIN_CB_QoE_opt = (sum(ADAPTIVE_MIN_CB_optimization_HH['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_HL['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_LH['QoE']) + sum(ADAPTIVE_MIN_CB_optimization_LL['QoE'])) / (4*8760)
ADAPTIVE_MIN_CB_QoE_HP = 1
ADAPTIVE_MIN_CB_QoE_sim = (sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HH['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_HL['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LH['QoE']) + sum(ADAPTIVE_MIN_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
ADAPTIVE_MIN_CB_QoE_seq = (sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HH['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_HL['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LH['QoE']) + sum(ADAPTIVE_MIN_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

ADAPTIVE_MIN_CB_CB_opt = (sum(ADAPTIVE_MIN_CB_a_HH) + sum(ADAPTIVE_MIN_CB_a_HL) + sum(ADAPTIVE_MIN_CB_a_LH) + sum(ADAPTIVE_MIN_CB_a_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_HP = (sum(ADAPTIVE_MIN_CB_b_HH) + sum(ADAPTIVE_MIN_CB_b_HL) + sum(ADAPTIVE_MIN_CB_b_LH) + sum(ADAPTIVE_MIN_CB_b_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_sim = (sum(ADAPTIVE_MIN_CB_c_HH) + sum(ADAPTIVE_MIN_CB_c_HL) + sum(ADAPTIVE_MIN_CB_c_LH) + sum(ADAPTIVE_MIN_CB_c_LL)) / (8760*4)
ADAPTIVE_MIN_CB_CB_seq = (sum(ADAPTIVE_MIN_CB_d_HH) + sum(ADAPTIVE_MIN_CB_d_HL) + sum(ADAPTIVE_MIN_CB_d_LH) + sum(ADAPTIVE_MIN_CB_d_LL)) / (8760*4)

#CONSTANT_AVG_CB_
CONSTANT_AVG_CB_QoE_opt = (sum(CONSTANT_AVG_CB_optimization_HH['QoE']) + sum(CONSTANT_AVG_CB_optimization_HL['QoE']) + sum(CONSTANT_AVG_CB_optimization_LH['QoE']) + sum(CONSTANT_AVG_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_AVG_CB_QoE_HP = 1
CONSTANT_AVG_CB_QoE_sim = (sum(CONSTANT_AVG_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_AVG_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_AVG_CB_QoE_seq = (sum(CONSTANT_AVG_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_AVG_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_AVG_CB_CB_opt = (sum(CONSTANT_AVG_CB_a_HH) + sum(CONSTANT_AVG_CB_a_HL) + sum(CONSTANT_AVG_CB_a_LH) + sum(CONSTANT_AVG_CB_a_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_HP = (sum(CONSTANT_AVG_CB_b_HH) + sum(CONSTANT_AVG_CB_b_HL) + sum(CONSTANT_AVG_CB_b_LH) + sum(CONSTANT_AVG_CB_b_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_sim = (sum(CONSTANT_AVG_CB_c_HH) + sum(CONSTANT_AVG_CB_c_HL) + sum(CONSTANT_AVG_CB_c_LH) + sum(CONSTANT_AVG_CB_c_LL)) / (8760*4)
CONSTANT_AVG_CB_CB_seq = (sum(CONSTANT_AVG_CB_d_HH) + sum(CONSTANT_AVG_CB_d_HL) + sum(CONSTANT_AVG_CB_d_LH) + sum(CONSTANT_AVG_CB_d_LL)) / (8760*4)

#CONSTANT_HIGH_CB_
CONSTANT_HIGH_CB_QoE_opt = (sum(CONSTANT_HIGH_CB_optimization_HH['QoE']) + sum(CONSTANT_HIGH_CB_optimization_HL['QoE']) + sum(CONSTANT_HIGH_CB_optimization_LH['QoE']) + sum(CONSTANT_HIGH_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_HIGH_CB_QoE_HP = 1
CONSTANT_HIGH_CB_QoE_sim = (sum(CONSTANT_HIGH_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_HIGH_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_HIGH_CB_QoE_seq = (sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_HIGH_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_HIGH_CB_CB_opt = (sum(CONSTANT_HIGH_CB_a_HH) + sum(CONSTANT_HIGH_CB_a_HL) + sum(CONSTANT_HIGH_CB_a_LH) + sum(CONSTANT_HIGH_CB_a_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_HP = (sum(CONSTANT_HIGH_CB_b_HH) + sum(CONSTANT_HIGH_CB_b_HL) + sum(CONSTANT_HIGH_CB_b_LH) + sum(CONSTANT_HIGH_CB_b_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_sim = (sum(CONSTANT_HIGH_CB_c_HH) + sum(CONSTANT_HIGH_CB_c_HL) + sum(CONSTANT_HIGH_CB_c_LH) + sum(CONSTANT_HIGH_CB_c_LL)) / (8760*4)
CONSTANT_HIGH_CB_CB_seq = (sum(CONSTANT_HIGH_CB_d_HH) + sum(CONSTANT_HIGH_CB_d_HL) + sum(CONSTANT_HIGH_CB_d_LH) + sum(CONSTANT_HIGH_CB_d_LL)) / (8760*4)

#CONSTANT_LOW_CB_
CONSTANT_LOW_CB_QoE_opt = (sum(CONSTANT_LOW_CB_optimization_HH['QoE']) + sum(CONSTANT_LOW_CB_optimization_HL['QoE']) + sum(CONSTANT_LOW_CB_optimization_LH['QoE']) + sum(CONSTANT_LOW_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_LOW_CB_QoE_HP = 1
CONSTANT_LOW_CB_QoE_sim = (sum(CONSTANT_LOW_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_LOW_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_LOW_CB_QoE_seq = (sum(CONSTANT_LOW_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_LOW_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_LOW_CB_CB_opt = (sum(CONSTANT_LOW_CB_a_HH) + sum(CONSTANT_LOW_CB_a_HL) + sum(CONSTANT_LOW_CB_a_LH) + sum(CONSTANT_LOW_CB_a_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_HP = (sum(CONSTANT_LOW_CB_b_HH) + sum(CONSTANT_LOW_CB_b_HL) + sum(CONSTANT_LOW_CB_b_LH) + sum(CONSTANT_LOW_CB_b_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_sim = (sum(CONSTANT_LOW_CB_c_HH) + sum(CONSTANT_LOW_CB_c_HL) + sum(CONSTANT_LOW_CB_c_LH) + sum(CONSTANT_LOW_CB_c_LL)) / (8760*4)
CONSTANT_LOW_CB_CB_seq = (sum(CONSTANT_LOW_CB_d_HH) + sum(CONSTANT_LOW_CB_d_HL) + sum(CONSTANT_LOW_CB_d_LH) + sum(CONSTANT_LOW_CB_d_LL)) / (8760*4)

#CONSTANT_MAX_CB_
CONSTANT_MAX_CB_QoE_opt = (sum(CONSTANT_MAX_CB_optimization_HH['QoE']) + sum(CONSTANT_MAX_CB_optimization_HL['QoE']) + sum(CONSTANT_MAX_CB_optimization_LH['QoE']) + sum(CONSTANT_MAX_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_MAX_CB_QoE_HP = 1
CONSTANT_MAX_CB_QoE_sim = (sum(CONSTANT_MAX_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_MAX_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_MAX_CB_QoE_seq = (sum(CONSTANT_MAX_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_MAX_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_MAX_CB_CB_opt = (sum(CONSTANT_MAX_CB_a_HH) + sum(CONSTANT_MAX_CB_a_HL) + sum(CONSTANT_MAX_CB_a_LH) + sum(CONSTANT_MAX_CB_a_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_HP = (sum(CONSTANT_MAX_CB_b_HH) + sum(CONSTANT_MAX_CB_b_HL) + sum(CONSTANT_MAX_CB_b_LH) + sum(CONSTANT_MAX_CB_b_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_sim = (sum(CONSTANT_MAX_CB_c_HH) + sum(CONSTANT_MAX_CB_c_HL) + sum(CONSTANT_MAX_CB_c_LH) + sum(CONSTANT_MAX_CB_c_LL)) / (8760*4)
CONSTANT_MAX_CB_CB_seq = (sum(CONSTANT_MAX_CB_d_HH) + sum(CONSTANT_MAX_CB_d_HL) + sum(CONSTANT_MAX_CB_d_LH) + sum(CONSTANT_MAX_CB_d_LL)) / (8760*4)

#CONSTANT_MIN_CB_
CONSTANT_MIN_CB_QoE_opt = (sum(CONSTANT_MIN_CB_optimization_HH['QoE']) + sum(CONSTANT_MIN_CB_optimization_HL['QoE']) + sum(CONSTANT_MIN_CB_optimization_LH['QoE']) + sum(CONSTANT_MIN_CB_optimization_LL['QoE'])) / (4*8760)
CONSTANT_MIN_CB_QoE_HP = 1
CONSTANT_MIN_CB_QoE_sim = (sum(CONSTANT_MIN_CB_simpleCarbonAware_HH['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_HL['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LH['QoE']) + sum(CONSTANT_MIN_CB_simpleCarbonAware_LL['QoE'])) / (4*8760)
CONSTANT_MIN_CB_QoE_seq = (sum(CONSTANT_MIN_CB_sequentialCarbonAware_HH['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_HL['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LH['QoE']) + sum(CONSTANT_MIN_CB_sequentialCarbonAware_LL['QoE'])) / (4*8760)

CONSTANT_MIN_CB_CB_opt = (sum(CONSTANT_MIN_CB_a_HH) + sum(CONSTANT_MIN_CB_a_HL) + sum(CONSTANT_MIN_CB_a_LH) + sum(CONSTANT_MIN_CB_a_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_HP = (sum(CONSTANT_MIN_CB_b_HH) + sum(CONSTANT_MIN_CB_b_HL) + sum(CONSTANT_MIN_CB_b_LH) + sum(CONSTANT_MIN_CB_b_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_sim = (sum(CONSTANT_MIN_CB_c_HH) + sum(CONSTANT_MIN_CB_c_HL) + sum(CONSTANT_MIN_CB_c_LH) + sum(CONSTANT_MIN_CB_c_LL)) / (8760*4)
CONSTANT_MIN_CB_CB_seq = (sum(CONSTANT_MIN_CB_d_HH) + sum(CONSTANT_MIN_CB_d_HL) + sum(CONSTANT_MIN_CB_d_LH) + sum(CONSTANT_MIN_CB_d_LL)) / (8760*4)



# Define plot limits 
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()

# Create a rectangle patch for the entire area
background_patch = Rectangle(xy=(0, 0),
                             width=x_max - x_min,
                             height=y_max - y_min,
                             color='lightgreen',  # Set to your desired color
                             alpha=0.5,  # Set transparency (0 to 1)
                             zorder=0.1)

# Add the patch to the axes 
ax = plt.gca()  # Get current axes object
ax.add_patch(background_patch)


# QoE values 
qoe_coord = [ADAPTIVE_AVG_CB_QoE_opt, ADAPTIVE_AVG_CB_QoE_HP, ADAPTIVE_AVG_CB_QoE_sim, ADAPTIVE_AVG_CB_QoE_seq, 
             ADAPTIVE_MAX_CB_QoE_opt, ADAPTIVE_MAX_CB_QoE_HP, ADAPTIVE_MAX_CB_QoE_sim, ADAPTIVE_MAX_CB_QoE_seq, 
             ADAPTIVE_MIN_CB_QoE_opt, ADAPTIVE_MIN_CB_QoE_HP, ADAPTIVE_MIN_CB_QoE_sim, ADAPTIVE_MIN_CB_QoE_seq, 
             CONSTANT_AVG_CB_QoE_opt, CONSTANT_AVG_CB_QoE_HP, CONSTANT_AVG_CB_QoE_sim, CONSTANT_AVG_CB_QoE_seq,
             CONSTANT_HIGH_CB_QoE_opt, CONSTANT_HIGH_CB_QoE_HP, CONSTANT_HIGH_CB_QoE_sim, CONSTANT_HIGH_CB_QoE_seq, 
             CONSTANT_LOW_CB_QoE_opt, CONSTANT_LOW_CB_QoE_HP, CONSTANT_LOW_CB_QoE_sim, CONSTANT_LOW_CB_QoE_seq, 
             CONSTANT_MAX_CB_QoE_opt, CONSTANT_MAX_CB_QoE_HP, CONSTANT_MAX_CB_QoE_sim, CONSTANT_MAX_CB_QoE_seq, 
             CONSTANT_MIN_CB_QoE_opt, CONSTANT_MIN_CB_QoE_HP, CONSTANT_MIN_CB_QoE_sim, CONSTANT_MIN_CB_QoE_seq]

# CB values 
cb_coord = [ADAPTIVE_AVG_CB_CB_opt, ADAPTIVE_AVG_CB_CB_HP, ADAPTIVE_AVG_CB_CB_sim, ADAPTIVE_AVG_CB_CB_seq,
            ADAPTIVE_MAX_CB_CB_opt, ADAPTIVE_MAX_CB_CB_HP, ADAPTIVE_MAX_CB_CB_sim, ADAPTIVE_MAX_CB_CB_seq,
            ADAPTIVE_MIN_CB_CB_opt, ADAPTIVE_MIN_CB_CB_HP, ADAPTIVE_MIN_CB_CB_sim, ADAPTIVE_MIN_CB_CB_seq,
            CONSTANT_AVG_CB_CB_opt, CONSTANT_AVG_CB_CB_HP, CONSTANT_AVG_CB_CB_sim, CONSTANT_AVG_CB_CB_seq,
            CONSTANT_HIGH_CB_CB_opt, CONSTANT_HIGH_CB_CB_HP, CONSTANT_HIGH_CB_CB_sim, CONSTANT_HIGH_CB_CB_seq,
            CONSTANT_LOW_CB_CB_opt, CONSTANT_LOW_CB_CB_HP, CONSTANT_LOW_CB_CB_sim, CONSTANT_LOW_CB_CB_seq,
            CONSTANT_MAX_CB_CB_opt, CONSTANT_MAX_CB_CB_HP, CONSTANT_MAX_CB_CB_sim, CONSTANT_MAX_CB_CB_seq,
            CONSTANT_MIN_CB_CB_opt, CONSTANT_MIN_CB_CB_HP, CONSTANT_MIN_CB_CB_sim, CONSTANT_MIN_CB_CB_seq]

# Labels for QoE data points
labels = ['Optimal', 'High Performance', 'Simple CA', 'Sequential CA']

shape = ['p', 'x', 'o', '*'] * 8

colors = (['#2CC820'] + ['#FB5534'] + ['#22CAD8'] + ['orange']) * 8 

plt.ylim(0, 1.2)  # Set Y-axis limits from 0 to 1
plt.xlim(xmin=0, xmax=np.max(cb_coord)+1)


# Plot QoE data points with individual labels
for i, (w, z) in enumerate(zip(cb_coord, qoe_coord)):
    if i<4:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
    else:
        plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)


# Label the axes
plt.xlabel('Carbon Budget % (CB)')
plt.ylabel('Quality of Experience % (QoE)')

# Add a title 
plt.title('QoE vs. Carbon Budget')

# Add legend
plt.legend()
plt.savefig("../img/temp/multiObjective2.png", bbox_inches = "tight")
# Show the plot
plt.show()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\3899785320.py:144: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', label = labels[i], alpha=0.7)  # Customize plot style
# C:\Users\rober\AppData\Local\Temp\ipykernel_16824\3899785320.py:146: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(w, z, marker=shape[i], color = colors[i], s=150, edgecolor='black', alpha=0.7)
